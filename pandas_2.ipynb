# %% [markdown]
# pandas is a machine learning library help to prepare data frame for training

# %% [markdown]
# importing pandas

# %%
import pandas as pd

# %% [markdown]
# python file handling

# %%
path=open("english-corpus.txt","r")
print(path.readline())
print(path.readline())
# Out:
# is zain your nephew
#
# i wish youd trust me

# %%
with open("english-corpus.txt","r") as file:
    print(file.read(10))
# Out:
# is zain yo

# %%
file=open("english-corpus.txt","r")
while True:
    line = file.readline()
    if not line:
        break
    print(line)
# Out:
# is zain your nephew
#
# i wish youd trust me
#
# did he touch you
#
# its part of life
#
# zain isnt ugly
#
# above all be patient
#
# i learned it from him
#
# why am i doing this
#
# i made a bad decision
#
# zain wont care
#
# zain was hesitant
#
# i borrowed zains car
#
# why are you out here
#
# he is just a liar
#
# were almost done
#
# what is happening
#
# zain betrayed us
#
# zain goofed
#
# everythings fine
#
# is it for here
#
# did zain give you that
#
# come on wake up
#
# zain needs the ladder
#
# i am not tired yet
#
# i am very tired
#
# he is full of energy
#
# i have got no worries
#
# wheres my coat
#
# i am game
#
# he likes it very much
#
# i come from china
#
# shes a bad liar
#
# the roses smell nice
#
# nobodys seen tom
#
# he will not go
#
# i dont doubt that
#
# this is selling at throw away price
#
# lets give it a try
#
# you are a doctor
#
# i think zain is normal
#
# is it white
#
# what is the commotion
#
# send it in duplicate
#
# ...

# %%
print(file.read())

# %% [markdown]
# writing in python here w overwrites the file

# %%
lines=["this is new line 1", "this is new line 2", "this is new line 3"]
with open("practice.txt","w") as file:
    for i in lines:
        file.write(i+"\n")

# %%
with open("practice.txt","r") as file:
   print(file.readline())
# Out:
# this is new line 1

# %%
import pandas as pd

# %% [markdown]
# importing numpy for declaring arrays

# %%
import numpy as np
data=np.random.randint(1,10,size=5)
data
# Out:
# array([3, 9, 6, 4, 4])

# %% [markdown]
# making series of array

# %%
df=pd.Series(data)
df
# Out:
# 0    3
# 1    9
# 2    6
# 3    4
# 4    4
# dtype: int32

# %%
print(df[2])
# Out:
# 6

# %%
print(df.isnull)
# Out:
# <bound method Series.isnull of 0    3
# 1    9
# 2    6
# 3    4
# 4    4
# dtype: int32>

# %% [markdown]
# making pandas dataframe

# %%
data={'Name':['karrar','arham','khizer'],'age':[8,4,2],'city':['karachi','islamabad','islamabad']}
df=pd.DataFrame(data)
df['Name']
# Out:
# 0    karrar
# 1     arham
# 2    khizer
# Name: Name, dtype: object

# %%
df
# Out:
#      Name  age       city
# 0  karrar    8    karachi
# 1   arham    4  islamabad
# 2  khizer    2  islamabad

# %% [markdown]
# check to print age greater than 6

# %%
df['age']>6
# Out:
# 0     True
# 1    False
# 2    False
# Name: age, dtype: bool

# %% [markdown]
# storing dataframe into .csv file

# %%
df.to_csv('train.csv',index=False)

# %% [markdown]
# reading the csv file

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      Name  age       city
# 0  karrar    8    karachi
# 1   arham    4  islamabad
# 2  khizer    2  islamabad

# %% [markdown]
# making new pandas data frame

# %%
newdata={'Name':['israr','suhail','burhan','tatheer','kashan','kamla'],'age':[10,11,8,5,16,8],'city':['khalpu','khalpu','khalpu','khalpu','khalpu','khalpu']}
df=pd.DataFrame(newdata)
df
# Out:
#       Name  age    city
# 0    israr   10  khalpu
# 1   suhail   11  khalpu
# 2   burhan    8  khalpu
# 3  tatheer    5  khalpu
# 4   kashan   16  khalpu
# 5    kamla    8  khalpu

# %%
df.to_csv("train.txt")

# %%
df=pd.read_csv("train.txt")
df
# Out:
#    Unnamed: 0     Name  age    city
# 0           0    israr   10  khalpu
# 1           1   suhail   11  khalpu
# 2           2   burhan    8  khalpu
# 3           3  tatheer    5  khalpu
# 4           4   kashan   16  khalpu
# 5           5    kamla    8  khalpu

# %% [markdown]
# sorting in python

# %%
data=['ali','zaki','muhammad','junaid','curan']
print(data.sort())
# Out:
# None

# %%
print(sorted(data,reverse=False))
# Out:
# ['ali', 'curan', 'junaid', 'muhammad', 'zaki']

# %%
array=np.random.randint(1,20,size=10)
array
# Out:
# array([ 2, 17, 12,  5,  3, 17,  4, 12, 15,  3])

# %%
print(array.sort())
# Out:
# None

# %%
print(sorted(array,reverse=True))
# Out:
# [17, 17, 15, 12, 12, 5, 4, 3, 3, 2]

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      Name  age       city
# 0  karrar    8    karachi
# 1   arham    4  islamabad
# 2  khizer    2  islamabad

# %%
newdata={'Name':['israr','suhail','burhan','tatheer','kashan','kamla'],'age':[10,11,8,5,16,8],'city':['khalpu','khalpu','khalpu','khalpu','khalpu','khalpu']}
df=pd.DataFrame(newdata)
df
# Out:
#       Name  age    city
# 0    israr   10  khalpu
# 1   suhail   11  khalpu
# 2   burhan    8  khalpu
# 3  tatheer    5  khalpu
# 4   kashan   16  khalpu
# 5    kamla    8  khalpu

# %%
df.to_csv("train.csv")

# %%
df=pd.read_csv("train.csv")
df
# Out:
#    Unnamed: 0     Name  age    city
# 0           0    israr   10  khalpu
# 1           1   suhail   11  khalpu
# 2           2   burhan    8  khalpu
# 3           3  tatheer    5  khalpu
# 4           4   kashan   16  khalpu
# 5           5    kamla    8  khalpu

# %% [markdown]
# printing 1st five rows of file

# %%
df.head(5)
# Out:
#    Unnamed: 0     Name  age    city
# 0           0    israr   10  khalpu
# 1           1   suhail   11  khalpu
# 2           2   burhan    8  khalpu
# 3           3  tatheer    5  khalpu
# 4           4   kashan   16  khalpu

# %% [markdown]
# finding mean,median of age column

# %%
print(df['age'].mean(),df['age'].median())
# Out:
# 9.666666666666666 9.0

# %% [markdown]
# adding new column in the data frame

# %%
df['school']=['kpsc','kpsc','kpsc','kpsc','kpsc','kpsc']

# %%
df
# Out:
#    Unnamed: 0     Name  age    city school
# 0           0    israr   10  khalpu   kpsc
# 1           1   suhail   11  khalpu   kpsc
# 2           2   burhan    8  khalpu   kpsc
# 3           3  tatheer    5  khalpu   kpsc
# 4           4   kashan   16  khalpu   kpsc
# 5           5    kamla    8  khalpu   kpsc

# %%
x=df[['Name','age']]
x
# Out:
#       Name  age
# 0    israr   10
# 1   suhail   11
# 2   burhan    8
# 3  tatheer    5
# 4   kashan   16
# 5    kamla    8

# %% [markdown]
# accessing specific value using column and row number

# %%
x.iloc[0,1]
# Out:
# 10

# %%
df
# Out:
#       Name  age    city
# 0    israr   10  khalpu
# 1   suhail   11  khalpu
# 2   burhan    8  khalpu
# 3  tatheer    5  khalpu
# 4   kashan   16  khalpu
# 5    kamla    8  khalpu

# %%
df1=df.head(2)
df1
# Out:
#      Name  age    city
# 0   israr   10  khalpu
# 1  suhail   11  khalpu

# %%
df2=df.tail(2)
df2
# Out:
#      Name  age    city
# 4  kashan   16  khalpu
# 5   kamla    8  khalpu

# %%
merge=pd.merge(df1,df2,on=['age','city'])
merge
# Out:
# Empty DataFrame
# Columns: [Name_x, age, city, Name_y]
# Index: []

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   age     2 non-null      int64
#  2   city    2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 180.0+ bytes

# %%
print(df1.duplicated())
# Out:
# 0    False
# 1    False
# dtype: bool

# %%
print(df1.dropna())
# Out:
#      Name  age    city
# 0   israr   10  khalpu
# 1  suhail   11  khalpu

# %%
#df1['city'].replace('khaplu','khaplu',inplace=True)
d
# Out:
# 0    khalpu
# 1    khalpu
# Name: city, dtype: object

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.1.4

# %%
df=pd.read_csv("train.csv") #pd.read_jason("file.json") for .json file
df
# Out:
#    Unnamed: 0     Name  age    city
# 0           0    israr   10  khalpu
# 1           1   suhail   11  khalpu
# 2           2   burhan    8  khalpu
# 3           3  tatheer    5  khalpu
# 4           4   kashan   16  khalpu
# 5           5    kamla    8  khalpu

# %%
df.loc[[0,1,2,3]]
# Out:
#    Unnamed: 0     Name  age    city
# 0           0    israr   10  khalpu
# 1           1   suhail   11  khalpu
# 2           2   burhan    8  khalpu
# 3           3  tatheer    5  khalpu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6 non-null      int64
#  1   Name        6 non-null      object
#  2   age         6 non-null      int64
#  3   city        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df=pd.read_csv("rawdata.csv")
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %% [markdown]
# getting info of data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Duration     32 non-null     int64
#  1   Date  Pulse  31 non-null     object
#  2   Maxpulse     32 non-null     int64
#  3   Calories     32 non-null     int64
#  4   Unnamed: 4   30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# dropping the null value rows

# %%
newdf=df.dropna()
newdf
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %%
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %% [markdown]
# changing the original dataframe

# %%
df.dropna(inplace=True)
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %%
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %% [markdown]
# finding median and filling the null rows

# %%
df['Calories'].fillna(df['Calories'].median(),inplace=True)
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %% [markdown]
# converting data into correct format

# %%
df['Date Pulse']=pd.to_datetime(df['Date Pulse'])
df

# %% [markdown]
# replacing values

# %%
df.loc[7,'Calories']=135
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       135       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %% [markdown]
# dropping rows by filtering

# %%
for i in df.index:
    if df.loc[i,'Calories']>120:
        df.drop(i,inplace=True)
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 16        60  '2020/12/16'        98       120       215.2
# 17        60  '2020/12/17'       100       120       300.0
# 23        60  '2020/12/23'       130       101       300.0
# 26        60    12/26/2020       100       120       250.0
# 27        60  '2020/12/27'        92       118       241.0
# 31        60  '2020/12/31'        92       115       243.0

# %% [markdown]
# printing and removing duplicated values

# %%
df.duplicated()
# Out:
# 11    False
# 12     True
# 16    False
# 17    False
# 23    False
# 26    False
# 27    False
# 31    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)
df   #row 12 has been removed because it has same value as row 11 has
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 11        60  '2020/12/12'       100       120       250.7
# 16        60  '2020/12/16'        98       120       215.2
# 17        60  '2020/12/17'       100       120       300.0
# 23        60  '2020/12/23'       130       101       300.0
# 26        60    12/26/2020       100       120       250.0
# 27        60  '2020/12/27'        92       118       241.0
# 31        60  '2020/12/31'        92       115       243.0

# %%
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 11        60  '2020/12/12'       100       120       250.7
# 16        60  '2020/12/16'        98       120       215.2
# 17        60  '2020/12/17'       100       120       300.0
# 23        60  '2020/12/23'       130       101       300.0
# 26        60    12/26/2020       100       120       250.0
# 27        60  '2020/12/27'        92       118       241.0
# 31        60  '2020/12/31'        92       115       243.0

# %%
df=pd.read_csv("rawdata.csv")
dfnew=df.head(7)
dfnew
# Out:
#    Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0        60  '2020/12/01'       110       130       409.1
# 1        60  '2020/12/02'       117       145       479.0
# 2        60  '2020/12/03'       103       135       340.0
# 3        45  '2020/12/04'       109       175       282.4
# 4        45  '2020/12/05'       117       148       406.0
# 5        60  '2020/12/06'       102       127       300.0
# 6        60  '2020/12/07'       110       136       374.0

# %%
#showing relation between columns

# %%
dfnew.corr()#-1 to 1 nearest to 1 is the best relation

# %%
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %%
#Identify missing values in the DataFrame
missing=df.isnull()
missing #true for the missing values
# Out:
#     Duration  Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0      False        False     False     False       False
# 1      False        False     False     False       False
# 2      False        False     False     False       False
# 3      False        False     False     False       False
# 4      False        False     False     False       False
# 5      False        False     False     False       False
# 6      False        False     False     False       False
# 7      False        False     False     False       False
# 8      False        False     False     False       False
# 9      False        False     False     False       False
# 10     False        False     False     False       False
# 11     False        False     False     False       False
# 12     False        False     False     False       False
# 13     False        False     False     False       False
# 14     False        False     False     False       False
# ...

# %%
#Drop rows with any missing values
df.dropna(axis=0,inplace=True)
df #inplace changes the original dataframe
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %%
#Drop columns with any missing values
df.dropna(axis=1,inplace=True)
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %%
#Fill missing values with a specific value
df.fillna(value=123,inplace=True)
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %%
#Fill missing values using forward fill and backward fill methods
df.fillna(method='ffill',inplace=True)
df.fillna(method='bfill',inplace=True)
df
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_65648\2719824585.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_65648\2719824585.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',inplace=True)
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# ...

# %%
#Interpolate missing values
df=pd.read_csv("rawdata.csv")
df.interpolate(method='linear',inplace=True)
df
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_65648\2407801526.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear',inplace=True)
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# ...

# %%
#Convert a column to a different data type
type(df['Calories'])
df['Calories']=df['Calories'].astype(float)
df
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110     130.0       409.1
# 1         60  '2020/12/02'       117     145.0       479.0
# 2         60  '2020/12/03'       103     135.0       340.0
# 3         45  '2020/12/04'       109     175.0       282.4
# 4         45  '2020/12/05'       117     148.0       406.0
# 5         60  '2020/12/06'       102     127.0       300.0
# 6         60  '2020/12/07'       110     136.0       374.0
# 7        450  '2020/12/08'       104     134.0       253.3
# 8         30  '2020/12/09'       109     133.0       195.1
# 9         60  '2020/12/10'        98     124.0       269.0
# 10        60  '2020/12/11'       103     147.0       329.3
# 11        60  '2020/12/12'       100     120.0       250.7
# 12        60  '2020/12/12'       100     120.0       250.7
# 13        60  '2020/12/13'       106     128.0       345.3
# 14        60  '2020/12/14'       104     132.0       379.3
# ...

# %%
#Apply a function to transform the values of a column
df['Duration']=df['Duration'].apply(lambda x:x+1)
df['Duration']
# Out:
# 0     121
# 1     121
# 2     121
# 3      91
# 4      91
# 5     121
# 6     121
# 7     901
# 8      61
# 9     121
# 10    121
# 11    121
# 12    121
# 13    121
# 14    121
# 15    121
# 16    121
# 17    121
# 18     91
# 19    121
# 20     91
# 21    121
# 22     91
# 23    121
# 24     91
# 25    121
# 26    121
# 27    121
# 28    121
# 29    121
# 30    121
# 31    121
# Name: Duration, dtype: int64

# %%
#Normalize a column using Min-Max scaling
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.drop_duplicates(subset=['Calories'],inplace=True)
df
# Out:
#     Duration          Date  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# 15        60  '2020/12/15'        98       123       275.0
# ...

# %%
df['column which is string']=df['same column'].str.lower()

# %%
df['column']=df['column'].str.strip()

# %%
df['column']=df['column'].str.replace('old','new')

# %%
df=pd.read_csv("rawdata.csv")
dfnew=df.head(4)
dfnew
# Out:
#    Duration          Date  Maxpulse  Calories  Unnamed: 4
# 0        60  '2020/12/01'       110       130       409.1
# 1        60  '2020/12/02'       117       145       479.0
# 2        60  '2020/12/03'       103       135       340.0
# 3        45  '2020/12/04'       109       175       282.4

# %%
dfnew['Date']=pd.to_datetime(df['Date'],errors='coerce')
dfnew['Date']
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_65648\587457612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['Date']=pd.to_datetime(df['Date'],errors='coerce')
# 0   2020-12-01
# 1   2020-12-02
# 2   2020-12-03
# 3   2020-12-04
# Name: Date, dtype: datetime64[ns]

# %%
year=dfnew['Date'].dt.year
month=dfnew['Date'].dt.month
day=dfnew['Date'].dt.day
year,month,day
# Out:
# (0    2020
#  1    2020
#  2    2020
#  3    2020
#  Name: Date, dtype: int32,
#  0    12
#  1    12
#  2    12
#  3    12
#  Name: Date, dtype: int32,
#  0    1
#  1    2
#  2    3
#  3    4
#  Name: Date, dtype: int32)

# %%
filter=df[(df['Date']>='2020-12-01') & (df['Date']<='2020-12-03')]
filter
# Out:
# Empty DataFrame
# Columns: [Duration, Date, Maxpulse, Calories, Unnamed: 4, year]
# Index: []

# %%
df
# Out:
#     Duration          Date  Maxpulse  Calories  Unnamed: 4    year
# 0         60  '2020/12/01'       110       130       409.1  2020.0
# 1         60  '2020/12/02'       117       145       479.0  2020.0
# 2         60  '2020/12/03'       103       135       340.0  2020.0
# 3         45  '2020/12/04'       109       175       282.4  2020.0
# 4         45  '2020/12/05'       117       148       406.0     NaN
# 5         60  '2020/12/06'       102       127       300.0     NaN
# 6         60  '2020/12/07'       110       136       374.0     NaN
# 7        450  '2020/12/08'       104       134       253.3     NaN
# 8         30  '2020/12/09'       109       133       195.1     NaN
# 9         60  '2020/12/10'        98       124       269.0     NaN
# 10        60  '2020/12/11'       103       147       329.3     NaN
# 11        60  '2020/12/12'       100       120       250.7     NaN
# 12        60  '2020/12/12'       100       120       250.7     NaN
# ...

# %%
dfnew
# Out:
#    Duration       Date  Maxpulse  Calories  Unnamed: 4
# 0        60 2020-12-01       110       130       409.1
# 1        60 2020-12-02       117       145       479.0
# 2        60 2020-12-03       103       135       340.0
# 3        45 2020-12-04       109       175       282.4

# %%
merge=pd.merge(df,dfnew,on='Duration')
merge
# Out:
#     Duration        Date_x  Maxpulse_x  Calories_x  Unnamed: 4_x    year  \
# 0         60  '2020/12/01'         110         130         409.1  2020.0
# 1         60  '2020/12/01'         110         130         409.1  2020.0
# 2         60  '2020/12/01'         110         130         409.1  2020.0
# 3         60  '2020/12/02'         117         145         479.0  2020.0
# 4         60  '2020/12/02'         117         145         479.0  2020.0
# ..       ...           ...         ...         ...           ...     ...
# 73        45  '2020/12/05'         117         148         406.0     NaN
# 74        45  '2020/12/18'          90         112           NaN     NaN
# 75        45  '2020/12/20'          97         125         243.0     NaN
# 76        45           NaN         100         119         282.0     NaN
# 77        45  '2020/12/24'         105         132         246.0     NaN
#
#        Date_y  Maxpulse_y  Calories_y  Unnamed: 4_y
# ...

# %%
pd.concat([df,dfnew],axis=0)
# Out:
#     Duration                 Date  Maxpulse  Calories  Unnamed: 4    year
# 0         60         '2020/12/01'       110       130       409.1  2020.0
# 1         60         '2020/12/02'       117       145       479.0  2020.0
# 2         60         '2020/12/03'       103       135       340.0  2020.0
# 3         45         '2020/12/04'       109       175       282.4  2020.0
# 4         45         '2020/12/05'       117       148       406.0     NaN
# 5         60         '2020/12/06'       102       127       300.0     NaN
# 6         60         '2020/12/07'       110       136       374.0     NaN
# 7        450         '2020/12/08'       104       134       253.3     NaN
# 8         30         '2020/12/09'       109       133       195.1     NaN
# 9         60         '2020/12/10'        98       124       269.0     NaN
# 10        60         '2020/12/11'       103       147       329.3     NaN
# 11        60         '2020/12/12'       100       120       250.7     NaN
# ...

# %%
pd.concat([df,dfnew],axis=1)
# Out:
#     Duration          Date  Maxpulse  Calories  Unnamed: 4    year  Duration  \
# 0         60  '2020/12/01'       110       130       409.1  2020.0      60.0
# 1         60  '2020/12/02'       117       145       479.0  2020.0      60.0
# 2         60  '2020/12/03'       103       135       340.0  2020.0      60.0
# 3         45  '2020/12/04'       109       175       282.4  2020.0      45.0
# 4         45  '2020/12/05'       117       148       406.0     NaN       NaN
# 5         60  '2020/12/06'       102       127       300.0     NaN       NaN
# 6         60  '2020/12/07'       110       136       374.0     NaN       NaN
# 7        450  '2020/12/08'       104       134       253.3     NaN       NaN
# 8         30  '2020/12/09'       109       133       195.1     NaN       NaN
# 9         60  '2020/12/10'        98       124       269.0     NaN       NaN
# 10        60  '2020/12/11'       103       147       329.3     NaN       NaN
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("rawdata.csv")
df
# Out:
#     Duration          Date  Maxpulse  Calories  Unnamed: 4
# 0         60  '2020/12/01'       110       130       409.1
# 1         60  '2020/12/02'       117       145       479.0
# 2         60  '2020/12/03'       103       135       340.0
# 3         45  '2020/12/04'       109       175       282.4
# 4         45  '2020/12/05'       117       148       406.0
# 5         60  '2020/12/06'       102       127       300.0
# 6         60  '2020/12/07'       110       136       374.0
# 7        450  '2020/12/08'       104       134       253.3
# 8         30  '2020/12/09'       109       133       195.1
# 9         60  '2020/12/10'        98       124       269.0
# 10        60  '2020/12/11'       103       147       329.3
# 11        60  '2020/12/12'       100       120       250.7
# 12        60  '2020/12/12'       100       120       250.7
# 13        60  '2020/12/13'       106       128       345.3
# 14        60  '2020/12/14'       104       132       379.3
# ...

# %%
print(df.isnull())
# Out:
#     Duration   Date  Maxpulse  Calories  Unnamed: 4
# 0      False  False     False     False       False
# 1      False  False     False     False       False
# 2      False  False     False     False       False
# 3      False  False     False     False       False
# 4      False  False     False     False       False
# 5      False  False     False     False       False
# 6      False  False     False     False       False
# 7      False  False     False     False       False
# 8      False  False     False     False       False
# 9      False  False     False     False       False
# 10     False  False     False     False       False
# 11     False  False     False     False       False
# 12     False  False     False     False       False
# 13     False  False     False     False       False
# 14     False  False     False     False       False
# 15     False  False     False     False       False
# 16     False  False     False     False       False
# ...

# %%
import numpy as np
import matplotlib.pyplot as mlt

# %%
import matplotlib.pyplot as plt
import numpy as np
image_array = np.random.randint(0, 256, (100, 100, 3))
plt.imshow(image_array)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
arr=np.random.randint(0,256,(100,100,1))
plt.imshow(arr,cmap='gray')
plt.axis('off')
plt.show()
